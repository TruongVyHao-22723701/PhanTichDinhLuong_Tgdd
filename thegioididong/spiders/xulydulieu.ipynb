# %%
import pandas as pd
import re

# %%
# Đọc file Excel
df = pd.read_excel('dongho_products.xlsx')
df.head(5)
# Out:
#                               Name    Price  Old Price  \
# 0  SMILE KID 47 mm Trẻ em SL064-01   290000     349000
# 1         Q&Q 40 mm Nam C33A-002PY   490000     690000
# 2         ELIO 29.5 mm Nữ ES015-C2   390000    1190000
# 3         KORLEX 30 mm Nữ KS039-01  1350000    2700000
# 4       CASIO 35 mm Nữ LW-204-1ADF   702000    1081000
#
#                                            Promotion Thời gian sử dụng pin:  \
# 0  Nhập mã VNPAYTGDD4 giảm từ 50,000đ đến 100,000...           Khoảng 2 năm
# 1  Nhập mã VNPAYTGDD4 giảm từ 50,000đ đến 100,000...           Khoảng 2 năm
# 2  Nhập mã VNPAYTGDD4 giảm từ 50,000đ đến 100,000...           Khoảng 1 năm
# 3  Nhập mã VNPAYTGDD4 giảm từ 50,000đ đến 100,000...           Khoảng 4 năm
# 4  Nhập mã VNPAYTGDD4 giảm từ 50,000đ đến 100,000...           Khoảng 3 năm
#
#   Đối tượng sử dụng: Đường kính mặt: Độ dày mặt:              Kháng nước:  \
# 0             Trẻ em           47 mm       17 mm      5 ATM - Đi mưa, tắm
# 1                Nam           40 mm      8.2 mm  3 ATM - Rửa tay, đi mưa
# 2                 Nữ         29.5 mm      7.5 mm  3 ATM - Rửa tay, đi mưa
# 3                 Nữ           30 mm        8 mm      5 ATM - Đi mưa, tắm
# 4                 Nữ           35 mm      9.4 mm      5 ATM - Đi mưa, tắm
#
#   Nguồn năng lượng:  Chất liệu mặt kính: Thương hiệu của:  \
# 0               Pin                 Nhựa         Việt Nam
# 1               Pin  Kính khoáng Mineral         Nhật Bản
# 2               Pin  Kính khoáng Mineral         Việt Nam
# 3               Pin        Kính Sapphire         Việt Nam
# 4               Pin                 Nhựa         Nhật Bản
#
#                         Bình luận
# 0                        Hài lòng
# 1                             NaN
# 2    Nói chung sử dụng tốt và bền
# 3  Ít đeo nên cũng ko biết tốt ko
# 4          Xài êm làm ak, đẹp lắm

# %%
def process_name(name):
    # Loại bỏ từ "Mẫu mới" nếu có
    name = name.replace("Mẫu mới", "").strip()
    
    # Loại bỏ các chuỗi kích thước như 'xx mm', 'xx x yy mm', 'xx.x mm', hoặc 'xx × yy mm' và các thông tin giới tính
    clean_name = re.sub(r'\d+(\.\d+)?( x \d+(\.\d+)?| × \d+(\.\d+)?)*\s*mm|Nam|Nữ|Trẻ em|Unisex', '', name).strip()

    # Loại bỏ dấu gạch nối hoặc khoảng trắng không cần thiết
    clean_name = re.sub(r'\s*-\s*', '', clean_name).strip()

    # Loại bỏ từ "Eco-Drive" nếu có ở cuối chuỗi
    clean_name = re.sub(r'Eco-Drive$', '', clean_name).strip()

    # Tìm mã sản phẩm dựa trên định dạng mã (các chữ và số cuối)
    product_code = re.search(r'[A-Z0-9\/\-\.]+$', clean_name)
    
    # Tách tên sản phẩm và mã sản phẩm
    if product_code:
        name_only = clean_name.replace(product_code.group(), '').strip()
        code = product_code.group()
    else:
        name_only = clean_name
        code = "Unknown"
    
    return name_only, code

# Áp dụng hàm xử lý cho cột 'Name'
df['Tên sản phẩm'], df['Mã sản phẩm'] = zip(*df['Name'].apply(process_name))

# Đổi vị trí các cột nếu cần thiết (thêm vào đầu hoặc cuối DataFrame)
df = df[['Tên sản phẩm', 'Mã sản phẩm'] + [col for col in df.columns if col not in ['Tên sản phẩm', 'Mã sản phẩm']]]

# %%
# Xóa cột 'Name' khỏi dataframe
df.drop(columns=['Name'], inplace=True)

# %%
df.head(5)
# Out:
#   Tên sản phẩm Mã sản phẩm    Price  Old Price  \
# 0    SMILE KID     SL06401   290000     349000
# 1          Q&Q   C33A002PY   490000     690000
# 2         ELIO     ES015C2   390000    1190000
# 3       KORLEX     KS03901  1350000    2700000
# 4        CASIO   LW2041ADF   702000    1081000
#
#                                            Promotion Thời gian sử dụng pin:  \
# 0  Nhập mã VNPAYTGDD4 giảm từ 50,000đ đến 100,000...           Khoảng 2 năm
# 1  Nhập mã VNPAYTGDD4 giảm từ 50,000đ đến 100,000...           Khoảng 2 năm
# 2  Nhập mã VNPAYTGDD4 giảm từ 50,000đ đến 100,000...           Khoảng 1 năm
# 3  Nhập mã VNPAYTGDD4 giảm từ 50,000đ đến 100,000...           Khoảng 4 năm
# 4  Nhập mã VNPAYTGDD4 giảm từ 50,000đ đến 100,000...           Khoảng 3 năm
#
#   Đối tượng sử dụng: Đường kính mặt: Độ dày mặt:              Kháng nước:  \
# 0             Trẻ em           47 mm       17 mm      5 ATM - Đi mưa, tắm
# 1                Nam           40 mm      8.2 mm  3 ATM - Rửa tay, đi mưa
# 2                 Nữ         29.5 mm      7.5 mm  3 ATM - Rửa tay, đi mưa
# 3                 Nữ           30 mm        8 mm      5 ATM - Đi mưa, tắm
# 4                 Nữ           35 mm      9.4 mm      5 ATM - Đi mưa, tắm
#
#   Nguồn năng lượng:  Chất liệu mặt kính: Thương hiệu của:  \
# 0               Pin                 Nhựa         Việt Nam
# 1               Pin  Kính khoáng Mineral         Nhật Bản
# 2               Pin  Kính khoáng Mineral         Việt Nam
# 3               Pin        Kính Sapphire         Việt Nam
# 4               Pin                 Nhựa         Nhật Bản
#
#                         Bình luận
# 0                        Hài lòng
# 1                             NaN
# 2    Nói chung sử dụng tốt và bền
# 3  Ít đeo nên cũng ko biết tốt ko
# 4          Xài êm làm ak, đẹp lắm

# %%
# Hàm xử lý cột 'Promotion'
def process_promotion(promotion):
    # Tìm mã giảm giá
    discount_code = re.search(r'mã (\w+)', promotion)
    discount_code = discount_code.group(1) if discount_code else None

    # Tìm mức giảm tối thiểu và tối đa
    min_discount = re.search(r'giảm từ (\d{1,3}(?:,\d{3})*|\d+)', promotion)
    max_discount = re.search(r'đến (\d{1,3}(?:,\d{3})*|\d+)', promotion)

    # Chuyển đổi thành số nguyên
    min_discount = int(min_discount.group(1).replace(',', '')) if min_discount else None
    max_discount = int(max_discount.group(1).replace(',', '')) if max_discount else None

    # Tìm phương thức thanh toán khuyến mãi
    payment_method = re.search(r'thanh toán qua (\w+-\w+)', promotion)
    payment_method = payment_method.group(1) if payment_method else None
    
    return discount_code, min_discount, max_discount, payment_method

# Áp dụng hàm xử lý cho cột 'Promotion' để tạo các cột mới
df['Mã giảm giá'], df['Mức giảm tối thiểu'], df['Mức giảm tối đa'], df['Phương thức thanh toán nhận khuyến mãi'] = zip(*df['Promotion'].apply(process_promotion))

# %%
df.drop(columns="Promotion", inplace=True)

# %%
# Đưa các cột mới vào vị trí trước cột 'Old Price'
cols = df.columns.tolist()
new_order = cols[:2] + cols[-4:] + cols[2:-4]  # Đưa các cột mới vào vị trí trước cột 'Old Price'
df = df[new_order]

# %%
df.head(3)
# Out:
#   Tên sản phẩm Mã sản phẩm Mã giảm giá  Mức giảm tối thiểu  Mức giảm tối đa  \
# 0    SMILE KID     SL06401  VNPAYTGDD4               50000           100000
# 1          Q&Q   C33A002PY  VNPAYTGDD4               50000           100000
# 2         ELIO     ES015C2  VNPAYTGDD4               50000           100000
#
#   Phương thức thanh toán nhận khuyến mãi   Price  Old Price  \
# 0                               VNPAY-QR  290000     349000
# 1                               VNPAY-QR  490000     690000
# 2                               VNPAY-QR  390000    1190000
#
#   Thời gian sử dụng pin: Đối tượng sử dụng: Đường kính mặt: Độ dày mặt:  \
# 0           Khoảng 2 năm             Trẻ em           47 mm       17 mm
# 1           Khoảng 2 năm                Nam           40 mm      8.2 mm
# 2           Khoảng 1 năm                 Nữ         29.5 mm      7.5 mm
#
#                Kháng nước: Nguồn năng lượng:  Chất liệu mặt kính:  \
# 0      5 ATM - Đi mưa, tắm               Pin                 Nhựa
# 1  3 ATM - Rửa tay, đi mưa               Pin  Kính khoáng Mineral
# 2  3 ATM - Rửa tay, đi mưa               Pin  Kính khoáng Mineral
#
#   Thương hiệu của:                     Bình luận
# 0         Việt Nam                      Hài lòng
# 1         Nhật Bản                           NaN
# 2         Việt Nam  Nói chung sử dụng tốt và bền

# %%
# Hàm xử lý thời gian sử dụng pin
def process_battery_life(battery_life):
    if pd.isna(battery_life) or battery_life == '':
        return float('nan')  # Trả về NaN cho giá trị rỗng hoặc None
    
    months = 0  # Khởi tạo biến lưu số tháng
    if 'tháng' in battery_life:
        months_match = re.search(r'(\d+(\.\d+)?)', battery_life)  # Tìm số tháng
        if months_match:
            months += float(months_match.group(1))  # Cộng thêm số tháng (có thể là số thập phân)
    elif 'năm' in battery_life:
        years_match = re.search(r'(\d+(\.\d+)?)', battery_life)  # Tìm số năm
        if years_match:
            months += float(years_match.group(1)) * 12  # Chuyển đổi năm thành tháng
    
    return months  # Trả về số tháng dưới dạng float

# Xử lý cột 'Thời gian sử dụng pin'
df['Thời gian sử dụng pin:'] = df['Thời gian sử dụng pin:'].apply(process_battery_life)

# %%
# Đổi tên cột thành "Thời gian sử dụng pin (năm)"
df.rename(columns={'Thời gian sử dụng pin:': 'Thời gian sử dụng pin (tháng)'}, inplace=True)

# %%
df.head()
# Out:
#   Tên sản phẩm Mã sản phẩm Mã giảm giá  Mức giảm tối thiểu  Mức giảm tối đa  \
# 0    SMILE KID     SL06401  VNPAYTGDD4               50000           100000
# 1          Q&Q   C33A002PY  VNPAYTGDD4               50000           100000
# 2         ELIO     ES015C2  VNPAYTGDD4               50000           100000
# 3       KORLEX     KS03901  VNPAYTGDD4               50000           100000
# 4        CASIO   LW2041ADF  VNPAYTGDD4               50000           100000
#
#   Phương thức thanh toán nhận khuyến mãi    Price  Old Price  \
# 0                               VNPAY-QR   290000     349000
# 1                               VNPAY-QR   490000     690000
# 2                               VNPAY-QR   390000    1190000
# 3                               VNPAY-QR  1350000    2700000
# 4                               VNPAY-QR   702000    1081000
#
#    Thời gian sử dụng pin (tháng) Đối tượng sử dụng: Đường kính mặt:  \
# 0                           24.0             Trẻ em           47 mm
# 1                           24.0                Nam           40 mm
# 2                           12.0                 Nữ         29.5 mm
# 3                           48.0                 Nữ           30 mm
# 4                           36.0                 Nữ           35 mm
#
#   Độ dày mặt:              Kháng nước: Nguồn năng lượng:  Chất liệu mặt kính:  \
# 0       17 mm      5 ATM - Đi mưa, tắm               Pin                 Nhựa
# 1      8.2 mm  3 ATM - Rửa tay, đi mưa               Pin  Kính khoáng Mineral
# 2      7.5 mm  3 ATM - Rửa tay, đi mưa               Pin  Kính khoáng Mineral
# 3        8 mm      5 ATM - Đi mưa, tắm               Pin        Kính Sapphire
# 4      9.4 mm      5 ATM - Đi mưa, tắm               Pin                 Nhựa
#
#   Thương hiệu của:                       Bình luận
# 0         Việt Nam                        Hài lòng
# 1         Nhật Bản                             NaN
# 2         Việt Nam    Nói chung sử dụng tốt và bền
# 3         Việt Nam  Ít đeo nên cũng ko biết tốt ko
# 4         Nhật Bản          Xài êm làm ak, đẹp lắm

# %%
df.head()
# Out:
#   Tên sản phẩm Mã sản phẩm Mã giảm giá  Mức giảm tối thiểu  Mức giảm tối đa  \
# 0    SMILE KID     SL06401  VNPAYTGDD4               50000           100000
# 1          Q&Q   C33A002PY  VNPAYTGDD4               50000           100000
# 2         ELIO     ES015C2  VNPAYTGDD4               50000           100000
# 3       KORLEX     KS03901  VNPAYTGDD4               50000           100000
# 4        CASIO   LW2041ADF  VNPAYTGDD4               50000           100000
#
#   Phương thức thanh toán nhận khuyến mãi    Price  Old Price  \
# 0                               VNPAY-QR   290000     349000
# 1                               VNPAY-QR   490000     690000
# 2                               VNPAY-QR   390000    1190000
# 3                               VNPAY-QR  1350000    2700000
# 4                               VNPAY-QR   702000    1081000
#
#    Thời gian sử dụng pin (tháng) Đối tượng sử dụng: Đường kính mặt:  \
# 0                           24.0             Trẻ em           47 mm
# 1                           24.0                Nam           40 mm
# 2                           12.0                 Nữ         29.5 mm
# 3                           48.0                 Nữ           30 mm
# 4                           36.0                 Nữ           35 mm
#
#   Độ dày mặt:              Kháng nước: Nguồn năng lượng:  Chất liệu mặt kính:  \
# 0       17 mm      5 ATM - Đi mưa, tắm               Pin                 Nhựa
# 1      8.2 mm  3 ATM - Rửa tay, đi mưa               Pin  Kính khoáng Mineral
# 2      7.5 mm  3 ATM - Rửa tay, đi mưa               Pin  Kính khoáng Mineral
# 3        8 mm      5 ATM - Đi mưa, tắm               Pin        Kính Sapphire
# 4      9.4 mm      5 ATM - Đi mưa, tắm               Pin                 Nhựa
#
#   Thương hiệu của:                       Bình luận
# 0         Việt Nam                        Hài lòng
# 1         Nhật Bản                             NaN
# 2         Việt Nam    Nói chung sử dụng tốt và bền
# 3         Việt Nam  Ít đeo nên cũng ko biết tốt ko
# 4         Nhật Bản          Xài êm làm ak, đẹp lắm

# %%
# Hàm xử lý cột 'Kháng nước:'
def process_water_resistance(resistance):
    if pd.isna(resistance):  # Kiểm tra giá trị NaN
        return None
    
    match = re.match(r'(\d+)\s*ATM\s*-\s*(.*)', resistance)
    if match:
        level = int(match.group(1))  # Chuyển đổi mức kháng nước thành số
        return level
    return None

# Áp dụng hàm xử lý cho cột 'Kháng nước:'
df['Mức kháng nước']= df['Kháng nước:'].apply(process_water_resistance)

# Đổi tên cột 'Mức kháng nước' để thêm đơn vị 'ATM'
df.rename(columns={'Mức kháng nước': 'Mức kháng nước (ATM)'}, inplace=True)

# Xóa cột 'Kháng nước:' khỏi DataFrame
df.drop(columns=['Kháng nước:'], inplace=True)

# %%
df.head()
# Out:
#   Tên sản phẩm Mã sản phẩm Mã giảm giá  Mức giảm tối thiểu  Mức giảm tối đa  \
# 0    SMILE KID     SL06401  VNPAYTGDD4               50000           100000
# 1          Q&Q   C33A002PY  VNPAYTGDD4               50000           100000
# 2         ELIO     ES015C2  VNPAYTGDD4               50000           100000
# 3       KORLEX     KS03901  VNPAYTGDD4               50000           100000
# 4        CASIO   LW2041ADF  VNPAYTGDD4               50000           100000
#
#   Phương thức thanh toán nhận khuyến mãi    Price  Old Price  \
# 0                               VNPAY-QR   290000     349000
# 1                               VNPAY-QR   490000     690000
# 2                               VNPAY-QR   390000    1190000
# 3                               VNPAY-QR  1350000    2700000
# 4                               VNPAY-QR   702000    1081000
#
#    Thời gian sử dụng pin (tháng) Đối tượng sử dụng: Đường kính mặt:  \
# 0                           24.0             Trẻ em           47 mm
# 1                           24.0                Nam           40 mm
# 2                           12.0                 Nữ         29.5 mm
# 3                           48.0                 Nữ           30 mm
# 4                           36.0                 Nữ           35 mm
#
#   Độ dày mặt: Nguồn năng lượng:  Chất liệu mặt kính: Thương hiệu của:  \
# 0       17 mm               Pin                 Nhựa         Việt Nam
# 1      8.2 mm               Pin  Kính khoáng Mineral         Nhật Bản
# 2      7.5 mm               Pin  Kính khoáng Mineral         Việt Nam
# 3        8 mm               Pin        Kính Sapphire         Việt Nam
# 4      9.4 mm               Pin                 Nhựa         Nhật Bản
#
#                         Bình luận  Mức kháng nước (ATM)
# 0                        Hài lòng                   5.0
# 1                             NaN                   3.0
# 2    Nói chung sử dụng tốt và bền                   3.0
# 3  Ít đeo nên cũng ko biết tốt ko                   5.0
# 4          Xài êm làm ak, đẹp lắm                   5.0

# %%
# Hàm xử lý cho cột 'Đường kính mặt:'
def process_diameter(diameter):
    if pd.isna(diameter) or diameter == 'N/A':
        return None  # Trả về None cho giá trị NaN hoặc 'N/A'
    if isinstance(diameter, str):  # Kiểm tra xem có phải là chuỗi không
        # Tìm tất cả các số và mm
        match = re.match(r'(\d+(\.\d+)?)\s*mm', diameter)
        if match:
            return float(match.group(1))  # Trả về giá trị đầu tiên
        # Nếu có định dạng như "xx x yy mm", ta có thể lấy giá trị đầu tiên
        match_dimension = re.search(r'(\d+(\.\d+)?)\s*x\s*(\d+(\.\d+)?)\s*mm', diameter)
        if match_dimension:
            return float(match_dimension.group(1))  # Trả về giá trị đầu tiên
    return None  # Trả về None nếu không tìm thấy

# Hàm xử lý cho cột 'Độ dày mặt:'
def process_thickness(thickness):
    if pd.isna(thickness) or thickness == 'N/A':
        return None  # Trả về None cho giá trị NaN hoặc 'N/A'
    if isinstance(thickness, str):  # Kiểm tra xem có phải là chuỗi không
        match = re.match(r'(\d+(\.\d+)?)\s*mm', thickness)
        if match:
            return float(match.group(1))  # Chuyển đổi thành số thực
    return None  # Trả về None cho các giá trị không hợp lệ

# Ghi đè lên cột cũ với giá trị đã xử lý
df['Đường kính mặt:'] = df['Đường kính mặt:'].apply(process_diameter)
df['Độ dày mặt:'] = df['Độ dày mặt:'].apply(process_thickness)

# %%
# Đổi tên các cột với đơn vị trong ngoặc
df.rename(columns={
    'Đường kính mặt:': 'Đường kính mặt (mm)',
    'Độ dày mặt:': 'Độ dày mặt (mm)'
}, inplace=True)

# %%
df.head()
# Out:
#   Tên sản phẩm Mã sản phẩm Mã giảm giá  Mức giảm tối thiểu  Mức giảm tối đa  \
# 0    SMILE KID     SL06401  VNPAYTGDD4               50000           100000
# 1          Q&Q   C33A002PY  VNPAYTGDD4               50000           100000
# 2         ELIO     ES015C2  VNPAYTGDD4               50000           100000
# 3       KORLEX     KS03901  VNPAYTGDD4               50000           100000
# 4        CASIO   LW2041ADF  VNPAYTGDD4               50000           100000
#
#   Phương thức thanh toán nhận khuyến mãi    Price  Old Price  \
# 0                               VNPAY-QR   290000     349000
# 1                               VNPAY-QR   490000     690000
# 2                               VNPAY-QR   390000    1190000
# 3                               VNPAY-QR  1350000    2700000
# 4                               VNPAY-QR   702000    1081000
#
#    Thời gian sử dụng pin (tháng) Đối tượng sử dụng:  Đường kính mặt (mm)  \
# 0                           24.0             Trẻ em                 47.0
# 1                           24.0                Nam                 40.0
# 2                           12.0                 Nữ                 29.5
# 3                           48.0                 Nữ                 30.0
# 4                           36.0                 Nữ                 35.0
#
#    Độ dày mặt (mm) Nguồn năng lượng:  Chất liệu mặt kính: Thương hiệu của:  \
# 0             17.0               Pin                 Nhựa         Việt Nam
# 1              8.2               Pin  Kính khoáng Mineral         Nhật Bản
# 2              7.5               Pin  Kính khoáng Mineral         Việt Nam
# 3              8.0               Pin        Kính Sapphire         Việt Nam
# 4              9.4               Pin                 Nhựa         Nhật Bản
#
#                         Bình luận  Mức kháng nước (ATM)
# 0                        Hài lòng                   5.0
# 1                             NaN                   3.0
# 2    Nói chung sử dụng tốt và bền                   3.0
# 3  Ít đeo nên cũng ko biết tốt ko                   5.0
# 4          Xài êm làm ak, đẹp lắm                   5.0

# %%
# Thay thế các bình luận rỗng hoặc không ghi gì bằng "N/A"
df['Bình luận'] = df['Bình luận'].replace('', 'N/A')  # Thay thế chuỗi rỗng
df['Bình luận'] = df['Bình luận'].fillna('N/A')       # Thay thế giá trị None
df.head(20)
# Out:
#          Tên sản phẩm    Mã sản phẩm Mã giảm giá  Mức giảm tối thiểu  \
# 0           SMILE KID        SL06401  VNPAYTGDD4               50000
# 1                 Q&Q      C33A002PY  VNPAYTGDD4               50000
# 2                ELIO        ES015C2  VNPAYTGDD4               50000
# 3              KORLEX        KS03901  VNPAYTGDD4               50000
# 4               CASIO      LW2041ADF  VNPAYTGDD4               50000
# 5               CASIO   AEQ120W9AVDF  VNPAYTGDD4               50000
# 6           ELIO Xmas        EL09002  VNPAYTGDD4               50000
# 7               SKMEI         SK1749  VNPAYTGDD4               50000
# 8           SMILE KID        SL07001  VNPAYTGDD4               50000
# 9                ELIO        ES11701  VNPAYTGDD4               50000
# 10               ELIO        EL10101  VNPAYTGDD4               50000
# 11               ELIO        EC00402  VNPAYTGDD4               50000
# 12               ELIO        EL10001  VNPAYTGDD4               50000
# 13          SMILE KID        SL03101  VNPAYTGDD4               50000
# 14              CASIO  MTP1375D7AVDF  VNPAYTGDD4               50000
# 15  ELIO Elegant Lady        ES16601  VNPAYTGDD4               50000
# 16               ELIO        EL09202  VNPAYTGDD4               50000
# 17     ELIO Nắng Xuân        EL04101  VNPAYTGDD4               50000
# 18               ELIO        EL06202  VNPAYTGDD4               50000
# 19          SMILE KID        SL02101  VNPAYTGDD4               50000
#
#     Mức giảm tối đa Phương thức thanh toán nhận khuyến mãi    Price  \
# 0            100000                               VNPAY-QR   290000
# 1            100000                               VNPAY-QR   490000
# 2            100000                               VNPAY-QR   390000
# 3            100000                               VNPAY-QR  1350000
# 4            100000                               VNPAY-QR   702000
# 5            100000                               VNPAY-QR  1020000
# 6            100000                               VNPAY-QR   390000
# 7            100000                               VNPAY-QR   120000
# 8            100000                               VNPAY-QR   190000
# 9            100000                               VNPAY-QR   690000
# 10           100000                               VNPAY-QR   290000
# 11           100000                               VNPAY-QR   320000
# 12           100000                               VNPAY-QR   690000
# 13           100000                               VNPAY-QR   190000
# 14           100000                               VNPAY-QR  1795000
# 15           100000                               VNPAY-QR   890000
# 16           100000                               VNPAY-QR   690000
# 17           100000                               VNPAY-QR   490000
# 18           100000                               VNPAY-QR   690000
# 19           100000                               VNPAY-QR   120000
#
#     Old Price  Thời gian sử dụng pin (tháng) Đối tượng sử dụng:  \
# 0      349000                           24.0             Trẻ em
# 1      690000                           24.0                Nam
# 2     1190000                           12.0                 Nữ
# 3     2700000                           48.0                 Nữ
# 4     1081000                           36.0                 Nữ
# 5     1727000                          120.0                Nam
# 6     1290000                           24.0                 Nữ
# 7           0                           18.0             Trẻ em
# 8      290000                           18.0             Trẻ em
# 9     1290000                           24.0                 Nữ
# 10     990000                           24.0                 Nữ
# 11     990000                           24.0                 Nữ
# 12     990000                           24.0                 Nữ
# 13     290000                           18.0             Trẻ em
# 14    2394000                           24.0                Nam
# 15    1390000                           24.0                 Nữ
# 16    1290000                           24.0                 Nữ
# 17     890000                           36.0                 Nữ
# 18     990000                           36.0                 Nữ
# 19     150000                           12.0             Trẻ em
#
#     Đường kính mặt (mm)  Độ dày mặt (mm) Nguồn năng lượng:  \
# 0                  47.0             17.0               Pin
# 1                  40.0              8.2               Pin
# 2                  29.5              7.5               Pin
# 3                  30.0              8.0               Pin
# 4                  35.0              9.4               Pin
# 5                  52.0             17.0               Pin
# 6                  20.5              7.9               Pin
# 7                  36.0             20.0               Pin
# 8                  33.5              9.0               Pin
# 9                  30.0              8.0               Pin
# 10                 30.0              9.0               Pin
# 11                 28.0              7.6               Pin
# 12                 33.0              8.0               Pin
# 13                 30.0             10.0               Pin
# 14                 42.0              NaN               Pin
# 15                 28.0              8.0               Pin
# 16                 26.0              7.5               Pin
# 17                 28.0              9.0               Pin
# 18                 29.0              8.0               Pin
# 19                 34.0             11.5               Pin
#
#                 Chất liệu mặt kính: Thương hiệu của:  \
# 0                              Nhựa         Việt Nam
# 1               Kính khoáng Mineral         Nhật Bản
# 2               Kính khoáng Mineral         Việt Nam
# 3                     Kính Sapphire         Việt Nam
# 4                              Nhựa         Nhật Bản
# 5                        Nhựa Resin         Nhật Bản
# 6               Kính khoáng Mineral         Việt Nam
# 7                        Nhựa Resin       Trung Quốc
# 8                        Nhựa Resin         Việt Nam
# 9               Kính khoáng Mineral         Việt Nam
# 10              Kính khoáng Mineral         Việt Nam
# 11              Kính khoáng Mineral         Việt Nam
# 12              Kính khoáng Mineral         Việt Nam
# 13  Kính Acrylic (thủy tinh hữu cơ)         Việt Nam
# 14              Kính khoáng Mineral         Nhật Bản
# 15              Kính khoáng Mineral         Việt Nam
# 16              Kính khoáng Mineral         Việt Nam
# 17              Kính khoáng Mineral         Việt Nam
# 18              Kính khoáng Mineral         Việt Nam
# 19                       Nhựa Resin         Việt Nam
#
#                                             Bình luận  Mức kháng nước (ATM)
# 0                                            Hài lòng                   5.0
# 1                                                 N/A                   3.0
# 2                        Nói chung sử dụng tốt và bền                   3.0
# 3                      Ít đeo nên cũng ko biết tốt ko                   5.0
# 4                              Xài êm làm ak, đẹp lắm                   5.0
# 5                        Mẫu mã đẹp gia cả phải chăng                  10.0
# 6   Đồng hồ đẹp. Ok. Mấy bạn nữ tay nhỏ mua đeo hợ...                   3.0
# 7   Đồng hồ trẻ em nên cài giờ đứng im luôn không ...                   NaN
# 8   Dùng tốt . Nhìn đeo vào tay rất sang. Bé rất t...                   3.0
# 9        Sao đồng hồ mới mua mây ngay mak lại hết bin                   3.0
# 10                         Đồng hồ đẹp, tương đối tốt                   3.0
# 11                           Ung cái bụng mát cái dạ.                   3.0
# 12  Hàng đẹp. Đúng mẫu. Hàng mới 100 tuy nhiên là ...                   3.0
# 13      Dây đổi màu, đeo hơn 1 tuần bắt đầu vàng vàng                   3.0
# 14                                                N/A                   5.0
# 15                                                N/A                   3.0
# 16                     Đồng hồ chống nước đẹp lắm nhó                   3.0
# 17  Đồng hồ đẹp nhìn dễ thương. Mình săn sale ngày...                   3.0
# 18  Giao hàng nhanh, kiểu rất đẹp, giá cả hợp lý. ...                   3.0
# 19  Mới sử dụng cũng chưa biết nhưng m cũng thấy đ...                   NaN

# %%
# Thứ tự cột mong muốn
new_order = [
    'Tên sản phẩm', 'Mã sản phẩm', 'Mã giảm giá', 
    'Mức giảm tối thiểu', 'Mức giảm tối đa', 
    'Phương thức thanh toán nhận khuyến mãi', 
    'Price', 'Old Price', 'Thời gian sử dụng pin (tháng)', 
    'Đối tượng sử dụng:', 'Đường kính mặt (mm)', 
    'Độ dày mặt (mm)', 'Nguồn năng lượng:', 
    'Mức kháng nước (ATM)', 
    'Chất liệu mặt kính:', 'Thương hiệu của:', 
    'Bình luận'
]

# Sắp xếp lại cột
df = df[new_order]
df.head()
# Out:
#   Tên sản phẩm Mã sản phẩm Mã giảm giá  Mức giảm tối thiểu  Mức giảm tối đa  \
# 0    SMILE KID     SL06401  VNPAYTGDD4               50000           100000
# 1          Q&Q   C33A002PY  VNPAYTGDD4               50000           100000
# 2         ELIO     ES015C2  VNPAYTGDD4               50000           100000
# 3       KORLEX     KS03901  VNPAYTGDD4               50000           100000
# 4        CASIO   LW2041ADF  VNPAYTGDD4               50000           100000
#
#   Phương thức thanh toán nhận khuyến mãi    Price  Old Price  \
# 0                               VNPAY-QR   290000     349000
# 1                               VNPAY-QR   490000     690000
# 2                               VNPAY-QR   390000    1190000
# 3                               VNPAY-QR  1350000    2700000
# 4                               VNPAY-QR   702000    1081000
#
#    Thời gian sử dụng pin (tháng) Đối tượng sử dụng:  Đường kính mặt (mm)  \
# 0                           24.0             Trẻ em                 47.0
# 1                           24.0                Nam                 40.0
# 2                           12.0                 Nữ                 29.5
# 3                           48.0                 Nữ                 30.0
# 4                           36.0                 Nữ                 35.0
#
#    Độ dày mặt (mm) Nguồn năng lượng:  Mức kháng nước (ATM)  \
# 0             17.0               Pin                   5.0
# 1              8.2               Pin                   3.0
# 2              7.5               Pin                   3.0
# 3              8.0               Pin                   5.0
# 4              9.4               Pin                   5.0
#
#    Chất liệu mặt kính: Thương hiệu của:                       Bình luận
# 0                 Nhựa         Việt Nam                        Hài lòng
# 1  Kính khoáng Mineral         Nhật Bản                             N/A
# 2  Kính khoáng Mineral         Việt Nam    Nói chung sử dụng tốt và bền
# 3        Kính Sapphire         Việt Nam  Ít đeo nên cũng ko biết tốt ko
# 4                 Nhựa         Nhật Bản          Xài êm làm ak, đẹp lắm

# %%
# Xử lý tất cả các cột: thay thế các giá trị rỗng hoặc None bằng "N/A"
df.fillna('N/A', inplace=True)  # Thay thế giá trị None
df.replace('', 'N/A', inplace=True)  # Thay thế chuỗi rỗng
# Out:
# C:\Users\T&T\AppData\Local\Temp\ipykernel_10432\1666721214.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'N/A' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.fillna('N/A', inplace=True)  # Thay thế giá trị None

# %%
# Lưu DataFrame vào file Excel mới
df.to_excel('processed_data.xlsx', index=False)

print("Dữ liệu đã được lưu vào file 'processed_data.xlsx'.")
# Out:
# Dữ liệu đã được lưu vào file 'processed_data.xlsx'.

# %%
import pandas as pd
import json

# Giả sử bạn đã có DataFrame 'df' đã được xử lý

# Lưu dữ liệu vào file JSON
with open('DHDT_json_Processed.json', 'w', encoding='utf-8') as json_file:
    json.dump(df.to_dict(orient='records'), json_file, ensure_ascii=False, indent=4)

# Lưu DataFrame ra định dạng CSV
df.to_csv('DHDT_csv_Processed.csv', index=False, encoding='utf-8')

print("Dữ liệu đã được lưu vào file JSON và CSV.")
# Out:
# Dữ liệu đã được lưu vào file JSON và CSV.
